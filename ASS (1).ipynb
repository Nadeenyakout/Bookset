# %% [markdown]
# # IMPORTING THE DATASET

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv("C:/Users/yakou/OneDrive/Desktop/books.csv")

# %%
df.head()
# Out:
#    book_id  goodreads_book_id  best_book_id   work_id  books_count       isbn  \
# 0        1            2767052       2767052   2792775          272  439023483
# 1        2                  3             3   4640799          491  439554934
# 2        3              41865         41865   3212258          226  316015849
# 3        6           11870085      11870085  16827462          226  525478817
# 4       12           13335037      13335037  13155899          210   62024035
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780525e+12                   John Green                     2012.0
# 4  9.780062e+12                Veronica Roth                     2011.0
#
# ...

# %% [markdown]
# # DATA CLEANING

# %%
# REMOVING NULLS
print("Missing Values:")
print(df.isnull().sum())
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# Missing Values:
# book_id                        0
# goodreads_book_id              0
# best_book_id                   0
# work_id                        0
# books_count                    0
# isbn                          52
# isbn13                        44
# authors                        0
# original_publication_year      3
# original_title                52
# title                          0
# language_code                109
# average_rating                 0
# ratings_count                  0
# work_ratings_count             0
# work_text_reviews_count        0
# ratings_1                      0
# ratings_2                      0
# ratings_3                      0
# ratings_4                      0
# ratings_5                      0
# image_url                      0
# small_image_url                0
# dtype: int64
# book_id                      0
# goodreads_book_id            0
# best_book_id                 0
# work_id                      0
# ...

# %%
# Drop unnecessary columns
# df = df.drop(['goodreads_book_id', 'best_book_id', 'work_id', 'isbn', 'isbn13', 'language_code', 'image_url', 'small_image_url'], axis=1)

# %%
df.head()
# Out:
#    book_id  goodreads_book_id  best_book_id   work_id  books_count       isbn  \
# 0        1            2767052       2767052   2792775          272  439023483
# 1        2                  3             3   4640799          491  439554934
# 2        3              41865         41865   3212258          226  316015849
# 3        6           11870085      11870085  16827462          226  525478817
# 4       12           13335037      13335037  13155899          210   62024035
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780525e+12                   John Green                     2012.0
# 4  9.780062e+12                Veronica Roth                     2011.0
#
# ...

# %%
# Remove duplicates if any
df = df.drop_duplicates()

# %%
# Convert original_publication_year to integer and handle missing values
df['original_publication_year'] = df['original_publication_year'].fillna(0).astype(int)

# %% [markdown]
# # DATA PREPROCESSING

# %%
# Filter dataset for Harry Potter series
hp_df = df[df['title'].str.contains('Harry Potter')]

# %%
hp_df.head()
# Out:
#     book_id  goodreads_book_id  best_book_id  work_id  books_count  \
# 1         2                  3             3  4640799          491
# 6        18                  5             5  2402163          376
# 8        21                  2             2  2809203          307
# 9        23              15881         15881  6231171          398
# 10       24                  6             6  3046572          332
#
#           isbn        isbn13                                  authors  \
# 1    439554934  9.780440e+12              J.K. Rowling, Mary GrandPré
# 6   043965548X  9.780440e+12  J.K. Rowling, Mary GrandPré, Rufus Beck
# 8    439358078  9.780439e+12              J.K. Rowling, Mary GrandPré
# 9    439064864  9.780439e+12              J.K. Rowling, Mary GrandPré
# 10   439139600  9.780439e+12              J.K. Rowling, Mary GrandPré
#
#     original_publication_year                             original_title  ...  \
# ...

# %%
hp_df
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 1           2                  3             3   4640799          491
# 6          18                  5             5   2402163          376
# 8          21                  2             2   2809203          307
# 9          23              15881         15881   6231171          398
# 10         24                  6             6   3046572          332
# 11         25             136251        136251   2963218          263
# 12         27                  1             1  41335427          275
# 96        422             862041        862041   2962492           76
# 613      3753                 10            10  21457570            6
# 1036     7018             483445        483445    471792           42
#
#             isbn        isbn13                                  authors  \
# 1      439554934  9.780440e+12              J.K. Rowling, Mary GrandPré
# ...

# %%
# Convert necessary columns to appropriate data types
hp_df['books_count'] = hp_df['books_count'].astype(int)
hp_df['average_rating'] = hp_df['average_rating'].astype(float)
hp_df['ratings_count'] = hp_df['ratings_count'].astype(int)
hp_df['work_ratings_count'] = hp_df['work_ratings_count'].astype(int)
# Out:
# C:\Users\yakou\AppData\Local\Temp\ipykernel_20704\956749201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp_df['books_count'] = hp_df['books_count'].astype(int)
# C:\Users\yakou\AppData\Local\Temp\ipykernel_20704\956749201.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp_df['average_rating'] = hp_df['average_rating'].astype(float)
# C:\Users\yakou\AppData\Local\Temp\ipykernel_20704\956749201.py:4: SettingWithCopyWarning:
# ...

# %% [markdown]
# # ANALYSIS

# %%
# Find most selling Harry Potter books
most_selling_books = hp_df.sort_values(by='books_count', ascending=False)

# Print most selling Harry Potter books
print("Most Selling Harry Potter Books:")
print("-----------------------------")
for index, row in most_selling_books.iterrows():
    print(f"Title: {row['title']}")
    print(f"Books Sold: {row['books_count']}")
    print("-----------------------------")
# Out:
# Most Selling Harry Potter Books:
# -----------------------------
# Title: Harry Potter and the Sorcerer's Stone (Harry Potter, #1)
# Books Sold: 491
# -----------------------------
# Title: Harry Potter and the Chamber of Secrets (Harry Potter, #2)
# Books Sold: 398
# -----------------------------
# Title: Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)
# Books Sold: 376
# -----------------------------
# Title: Harry Potter and the Goblet of Fire (Harry Potter, #4)
# Books Sold: 332
# -----------------------------
# Title: Harry Potter and the Order of the Phoenix (Harry Potter, #5)
# Books Sold: 307
# -----------------------------
# Title: Harry Potter and the Half-Blood Prince (Harry Potter, #6)
# Books Sold: 275
# -----------------------------
# Title: Harry Potter and the Deathly Hallows (Harry Potter, #7)
# Books Sold: 263
# -----------------------------
# Title: Harry Potter Boxset (Harry Potter, #1-7)
# Books Sold: 76
# -----------------------------
# ...

# %%
# Calculate average rating of Harry Potter books
average_rating = hp_df['average_rating'].mean()

# %%
# Print average rating of Harry Potter books
print("Average Rating of Harry Potter Books:")
print("-------------------------------------")
print(f"Average Rating: {average_rating:.2f}")
print("-------------------------------------")
# Out:
# Average Rating of Harry Potter Books:
# -------------------------------------
# Average Rating: 4.49
# -------------------------------------

# %%
# Plotting the average rating of Harry Potter books
plt.figure(figsize=(10, 6))
plt.barh(hp_df['title'], hp_df['average_rating'], color='lightgreen')
plt.xlabel('Average Rating')
plt.ylabel('Book Title')
plt.title('Average Rating of Harry Potter Books')
plt.gca().invert_yaxis()
plt.show()
